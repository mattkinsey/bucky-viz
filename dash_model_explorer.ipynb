# %% [markdown]
# ## Bucky Model Explorer

# %% [markdown]
# Bucky-Forecast - https://github.com/mattkinsey/bucky-forecasts/<br>
# ReichLab Covid-Forecast - https://github.com/reichlab/covid19-forecast-hub<br>

# %%
from dash_explorer import *

# %%
# Use preloaded demo data
start_dash_demo()
# Out:
# /mnt/c/Users/smolijm1/Documents/FORE/Bucky_Model_Explorer/util/
# Model Explorer.
# -----------------
# Data loaded.
# Starting Dash Server.
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app 'dash_explorer' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on

# %%
# Use local data from Bucky Model Outputs and Reich Lab
# May need to configure paths to local repos in prepare_data() and associated RUN DATA string
start_dash()

# bucky_data_path = '/mnt/c/Users/<path>/bucky-output/'
# reichlab_data_path = '/mnt/c/Users/<path>/covid19-forecast-hub/'
# monday_str = '2022-08-15'  or today_str
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 3>()
#       1 # Use local data from Bucky Model Outputs and Reich Lab
#       2 # May need to configure paths to local repos in prepare_data() and associated RUN DATA string
# ----> 3 start_dash()
#
# NameError: name 'start_dash' is not defined

# %% [markdown]
# ![image.png](attachment:d44cc22b-a585-4538-8233-703ff28a5d76.png)
